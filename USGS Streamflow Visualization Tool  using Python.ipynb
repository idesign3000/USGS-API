# %%
import urllib.parse03441000
import urllib.request
import os
import pandas as pd
import numpy as np

# %%
station_number = input("What is the USGS Station ID?\t")
start_date = input("Start Date (YYYY-MM-DD):\t")
end_date = input("End Date (YYYY-MM-DD):\t")
folder = os.getcwd()
# Out:
# What is the USGS Station ID?	03441000
# Start Date (YYYY-MM-DD):	2024-9-1
# End Date (YYYY-MM-DD):	2024-9-28

# %%
section1 = 'https://nwis.waterdata.usgs.gov/nwis/dv?referred_module=sw&search_site_no='
section2 = '&search_site_no_match_type=exact&site_tp_cd=OC&site_tp_cd=OC-CO&site_tp_cd=ES&site_tp_cd='\
'LK&site_tp_cd=ST&site_tp_cd=ST-CA&site_tp_cd=ST-DCH&site_tp_cd=ST-TS&index_pmcode_00060=1&group_key='\
'NONE&sitefile_output_format=html_table&column_name=agency_cd&column_name=site_no&column_name=station_nm&range_selection=date_range&begin_date='
section3 = '&end_date='
section4 = '&format=rdb&date_format=YYYY-MM-DD&rdb_compression=value&list_of_search_criteria=search_site_no%2Csite_tp_cd%2Crealtime_parameter_selection'

link = (section1 + station_number + section2 + start_date + section3 + end_date + section4)
print("Click here to see the generated USGS link: \n",link)
# Out:
# Click here to see the generated USGS link:
#  https://nwis.waterdata.usgs.gov/nwis/dv?referred_module=sw&search_site_no=03441000&search_site_no_match_type=exact&site_tp_cd=OC&site_tp_cd=OC-CO&site_tp_cd=ES&site_tp_cd=LK&site_tp_cd=ST&site_tp_cd=ST-CA&site_tp_cd=ST-DCH&site_tp_cd=ST-TS&index_pmcode_00060=1&group_key=NONE&sitefile_output_format=html_table&column_name=agency_cd&column_name=site_no&column_name=station_nm&range_selection=date_range&begin_date=2024-9-1&end_date=2024-9-28&format=rdb&date_format=YYYY-MM-DD&rdb_compression=value&list_of_search_criteria=search_site_no%2Csite_tp_cd%2Crealtime_parameter_selection

# %%
USGS_page = urllib.request.urlopen(link)
downloaded_data = USGS_page.read()

# %%
type(downloaded_data)
# Out:
# bytes

# %%
str_data = downloaded_data.decode()
type(str_data)
str_data
# Out:
# "# ---------------------------------- WARNING ----------------------------------------\n# Some of the data that you have obtained from this U.S. Geological Survey database\n# may not have received Director's approval. Any such data values are qualified\n# as provisional and are subject to revision. Provisional data are released on the\n# condition that neither the USGS nor the United States Government may be held liable\n# for any damages resulting from its use.\n#\n# Additional info: https://waterdata.usgs.gov/provisional-data-statement/\n#\n# Contact:   gs-w_waterdata_support@usgs.gov\n# retrieved: 2024-09-28 08:13:02 EDT       (nadww02)\n#\n# Data for the following 1 site(s) are contained in this file\n#    USGS 03441000 DAVIDSON RIVER NEAR BREVARD, NC\n# -----------------------------------------------------------------------------------\n#\n# Data provided for site 03441000\n#            TS   parameter     statistic     Description\n#         87851       00060     00001     Discharge, cubic feet per second (Maximum)\n#         87852       00060     00002     Discharge, cubic feet per second (Minimum)\n#         87853       00060     00003     Discharge, cubic feet per second (Mean)\n#\n# Data-value qualification codes included in this output:\n#     P  Provisional data subject to revision.\n# \nagency_cd\tsite_no\tdatetime\t87853_00060_00003\t87853_00060_00003_cd\n5s\t15s\t20d\t14n\t10s\nUSGS\t03441000\t2024-09-01\t43.3\tP\nUSGS\t03441000\t2024-09-02\t44.4\tP\nUSGS\t03441000\t2024-09-03\t33.3\tP\nUSGS\t03441000\t2024-09-04\t31.2\tP\nUSGS\t03441000\t2024-09-05\t30.3\tP\nUSGS\t03441000\t2024-09-06\t30.9\tP\nUSGS\t03441000\t2024-09-07\t29.9\tP\nUSGS\t03441000\t2024-09-08\t29.7\tP\nUSGS\t03441000\t2024-09-09\t28.2\tP\nUSGS\t03441000\t2024-09-10\t27.5\tP\nUSGS\t03441000\t2024-09-11\t26.6\tP\nUSGS\t03441000\t2024-09-12\t27.2\tP\nUSGS\t03441000\t2024-09-13\t45.1\tP\nUSGS\t03441000\t2024-09-14\t50.3\tP\nUSGS\t03441000\t2024-09-15\t42.3\tP\nUSGS\t03441000\t2024-09-16\t35.9\tP\nUSGS\t03441000\t2024-09-17\t85.9\tP\nUSGS\t03441000\t2024-09-18\t84.0\tP\nUSGS\t03441000\t2024-09-19\t54.6\tP\nUSGS\t03441000\t2024-09-20\t43.0\tP\nUSGS\t03441000\t2024-09-21\t36.9\tP\nUSGS\t03441000\t2024-09-22\t34.7\tP\nUSGS\t03441000\t2024-09-23\t67.5\tP\nUSGS\t03441000\t2024-09-24\t73.3\tP\nUSGS\t03441000\t2024-09-25\t395\tP\nUSGS\t03441000\t2024-09-26\t2860\tP\nUSGS\t03441000\t2024-09-27\t4920\tP\n"

# %%
f_str_data = str_data.split('\n')
#f_str_data

# %%
station_name = ''

for line in range(len(f_str_data)):
    if f_str_data[line].startswith("#    USGS"):
        station_name=f_str_data[line][3:]
print(station_name)
# Out:
#   USGS 03441000 DAVIDSON RIVER NEAR BREVARD, NC

# %%
date_flow = ''

for line in range(len(f_str_data)):
    if f_str_data[line].startswith("USGS"):
        data = f_str_data[line][14:]
        columns = data.split('\t')
        rows = ','.join([columns[0],(columns[1])])
        date_flow += rows + '\n'
date_flow = date_flow.encode()

with open(folder+'/USGS_Data_for_' + station_number  + '.txt', 'wb') as text:
        text.write(date_flow)

# %%
filename = folder+'/USGS_Data_for_' + station_number  + '.txt'
columns = ['Date','Discharge (cfs)']
df = pd.read_csv(filename,header=None,names=columns,parse_dates=[0])
df=df.set_index(['Date'])
df['Discharge (cfs)']=pd.to_numeric(df['Discharge (cfs)'], errors='coerce')
df.tail()
# Out:
#             Discharge (cfs)
# Date
# 2024-09-23             67.5
# 2024-09-24             73.3
# 2024-09-25            395.0
# 2024-09-26           2860.0
# 2024-09-27           4920.0

# %%
df.plot(figsize=(14,5), title= station_name, xlabel="Time", ylabel="Discharge (cfs)");
